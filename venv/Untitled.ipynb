# %%
run analyse.py
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object
# apples     3
# oranges    0
# Name: June, dtype: int64
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2
#    Unemployment_Rate  Stock_Index_Price
# 0                6.1               1500
# 1                5.8               1520
# 2                5.7               1525
# 3                5.7               1523
# 4                5.8               1515
# 5                5.6               1540
# 6                5.5               1545
# 7                5.3               1560
# 8                5.2               1555
# 9                5.2               1565
