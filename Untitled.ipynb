# %%
import pandas as pd
import os 
pd.read_csv("F:/Fib_done/FIB/2013_save_bme_19-11-03.csv")
# Out:
#        Date:  Total_count  Msp_sum  Pref_1  Pref_2  Pref_3  Pref_4  Pref_5  \
# 0   20131225       477591    45839       0       0       0       0       0
# 1   20131208       480199    45530       0       0       0       0       0
# 2   20131221       477247    45791       0       0       0       0       0
# 3   20131218       476560    45706       0       0       0       0       0
# 4   20131230       478365    46077       0       0       0       0       0
# 5   20131112       477716    45276       0       0       0       0       0
# 6   20131124       478782    45364       0       0       0       0       0
# 7   20131220       476603    45749       0       0       0       0       0
# 8   20131120       478982    45387       0       0       0       0       0
# 9   20131228       477859    45918       0       0       0       0       0
# 10  20131213       480704    45642       0       0       0       0       0
# ...

# %%
df=pd.read_csv("F:/Fib_done/FIB/2013_save_bme_19-11-03.csv")
df.plot(kind='scatter',x='Date:',y='Total_count',color='red')
