# %%
import plotly.express as px
import pandas as pd
import numpy as np
import os 
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
#C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv
#D:/Users/Baki/Documents/GitHub/IP-stats-trends/venv/csv
bme = pd.read_csv("C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv/bme.csv",parse_dates=["Date"], index_col="Date")
vh1 = pd.read_csv("C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv/vh1.csv",parse_dates=["Date"], index_col="Date")
vh2 = pd.read_csv("C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv/vh2.csv",parse_dates=["Date"], index_col="Date")
sze = pd.read_csv("C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv/szeged.csv",parse_dates=["Date"], index_col="Date")
lin = pd.read_csv("C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv/linx.csv",parse_dates=["Date"], index_col="Date")
jin = pd.read_csv("C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv/jinx.csv",parse_dates=["Date"], index_col="Date")
eqi = pd.read_csv("C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv/eqix.csv",parse_dates=["Date"], index_col="Date")
syd = pd.read_csv("C:/Users/bakit/PycharmProjects/IP-stats-trends/venv/csv/sydney.csv",parse_dates=["Date"], index_col="Date")

for i in range(32):
    col='Msp_'+str(i+1)
    bme[col] = bme[col]/bme["Msp_sum"]
    vh1[col] = vh1[col]/vh1["Msp_sum"]
    vh2[col] = vh2[col]/vh2["Msp_sum"]
    sze[col] = sze[col]/sze["Msp_sum"]
    lin[col] = lin[col]/lin["Msp_sum"]
    jin[col] = jin[col]/jin["Msp_sum"]
    eqi[col] = eqi[col]/eqi["Msp_sum"]
    syd[col] = syd[col]/syd["Msp_sum"]


c=8
legend=('bme','vh1','vh2','szeged')
Index = list(set(list(bme.index) + list(vh1.index )+ list(vh2.index) + list(sze.index) ))
Index.sort()

df4 = pd.DataFrame({'bme': [bme.loc[Date, 'Msp_32'] if Date in bme.index else np.nan for Date in Index],
                    'vh1': [vh1.loc[Date, 'Msp_32'] if Date in vh1.index else np.nan for Date in Index],
                    'vh2': [vh2.loc[Date, 'Msp_32'] if Date in vh2.index else np.nan for Date in Index],
                    'szeged': [sze.loc[Date, 'Msp_32'] if Date in sze.index else np.nan for Date in Index],
                   },index = Index)

plot = df4.resample('M').mean().plot(figsize=(3,3))
plot.set_title('Msp_32')
plot.set(xlabel='Dátum', ylabel='db')
vals = plot.get_yticks()
plot.set_yticklabels(['{:,.3%}'.format(x) for x in vals])
plot.grid()



bme_pref = bme.copy()
for col in bme_pref.columns: 
    if "Msp" not in col:
        #print(col)        
        bme_pref.drop(columns=[col],inplace=True)
        

fig, axs = plt.subplots(3, 3,figsize=(9,9),constrained_layout=True)
for i in range(3):
    for j in range(3):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'bme': [bme.loc[Date, col] if Date in bme.index else np.nan for Date in Index],
                            'vh1': [vh1.loc[Date, col] if Date in vh1.index else np.nan for Date in Index],
                            'vh2': [vh2.loc[Date, col] if Date in vh2.index else np.nan for Date in Index],
                            'szeged': [sze.loc[Date, col] if Date in sze.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[i,j].plot(df4.resample('M').mean())
        axs[i,j].set_title(col)
        axs[i,j].legend(legend)
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])
    ax.grid()

    
fig, axs = plt.subplots(3, 3,figsize=(9,9), constrained_layout=True)
for i in range(3):
    for j in range(3):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'bme': [bme.loc[Date, col] if Date in bme.index else np.nan for Date in Index],
                            'vh1': [vh1.loc[Date, col] if Date in vh1.index else np.nan for Date in Index],
                            'vh2': [vh2.loc[Date, col] if Date in vh2.index else np.nan for Date in Index],
                            'szeged': [sze.loc[Date, col] if Date in sze.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[i,j].plot(df4.resample('M').mean())
        axs[i,j].set_title(col)
        axs[i,j].legend(legend)
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])
    ax.grid()

    
fig, axs = plt.subplots(1, 2,figsize=(6,3), constrained_layout=True)
for i in range(1):
    for j in range(2):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'bme': [bme.loc[Date, col] if Date in bme.index else np.nan for Date in Index],
                            'vh1': [vh1.loc[Date, col] if Date in vh1.index else np.nan for Date in Index],
                            'vh2': [vh2.loc[Date, col] if Date in vh2.index else np.nan for Date in Index],
                            'szeged': [sze.loc[Date, col] if Date in sze.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[j].plot(df4.resample('M').mean())
        axs[j].set_title(col)
        axs[j].legend(legend)
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])
    ax.grid()

# %%
c=8
legend=('linx','jinx','eqix','sydney')
Index = list(set(list(bme.index) + list(vh1.index )+ list(vh2.index) + list(sze.index) +list(lin.index) + list(jin.index )+ list(eqi.index) + list(syd.index)))
Index.sort()

df4 = pd.DataFrame({'linx': [lin.loc[Date, 'Msp_32'] if Date in lin.index else np.nan for Date in Index],
                    'jinx': [jin.loc[Date, 'Msp_32'] if Date in jin.index else np.nan for Date in Index],
                    'eqix': [eqi.loc[Date, 'Msp_32'] if Date in eqi.index else np.nan for Date in Index],
                    'sydney': [syd.loc[Date, 'Msp_32'] if Date in syd.index else np.nan for Date in Index],
                   },index = Index)

plot = df4.resample('M').mean().plot(figsize=(3,3))
plot.set_title('Msp_32')
plot.set(xlabel='Dátum', ylabel='db')
plot.grid()

bme_pref = bme.copy()
for col in bme_pref.columns: 
    if "Msp" not in col:
        #print(col)        
        bme_pref.drop(columns=[col],inplace=True)
        

fig, axs = plt.subplots(3, 3,figsize=(9,9),constrained_layout=True)
for i in range(3):
    for j in range(3):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'linx': [lin.loc[Date, col] if Date in lin.index else np.nan for Date in Index],
                            'jinx': [jin.loc[Date, col] if Date in jin.index else np.nan for Date in Index],
                            'eqix': [eqi.loc[Date, col] if Date in eqi.index else np.nan for Date in Index],
                            'sydney': [syd.loc[Date, col] if Date in syd.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[i,j].plot(df4.resample('M').mean())
        axs[i,j].set_title(col)
        axs[i,j].legend(legend)
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    ax.grid()
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])
    
fig, axs = plt.subplots(3, 3,figsize=(9,9), constrained_layout=True)
for i in range(3):
    for j in range(3):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'linx': [lin.loc[Date, col] if Date in lin.index else np.nan for Date in Index],
                            'jinx': [jin.loc[Date, col] if Date in jin.index else np.nan for Date in Index],
                            'eqix': [eqi.loc[Date, col] if Date in eqi.index else np.nan for Date in Index],
                            'sydney': [syd.loc[Date, col] if Date in syd.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[i,j].plot(df4.resample('M').mean())
        axs[i,j].set_title(col)
        axs[i,j].legend(legend)
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    ax.grid()
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])
    
fig, axs = plt.subplots(1, 3,figsize=(9,3), constrained_layout=True)
for i in range(1):
    for j in range(3):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'linx': [lin.loc[Date, col] if Date in lin.index else np.nan for Date in Index],
                            'jinx': [jin.loc[Date, col] if Date in jin.index else np.nan for Date in Index],
                            'eqix': [eqi.loc[Date, col] if Date in eqi.index else np.nan for Date in Index],
                            'sydney': [syd.loc[Date, col] if Date in syd.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[j].plot(df4.resample('M').mean())
        axs[j].set_title(col)
        axs[j].legend(legend)
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    ax.grid()
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])

# %%
c=8
legend=('linx','jinx','eqix','sydney','bme','vh1','vh2','szeged')
Index = list(set(list(bme.index) + list(vh1.index )+ list(vh2.index) + list(sze.index) +list(lin.index) + list(jin.index )+ list(eqi.index) + list(syd.index)))
Index.sort()

df4 = pd.DataFrame({'linx': [lin.loc[Date, 'Msp_32'] if Date in lin.index else np.nan for Date in Index],
                    'jinx': [jin.loc[Date, 'Msp_32'] if Date in jin.index else np.nan for Date in Index],
                    'eqix': [eqi.loc[Date, 'Msp_32'] if Date in eqi.index else np.nan for Date in Index],
                    'sydney': [syd.loc[Date, 'Msp_32'] if Date in syd.index else np.nan for Date in Index],
                    'bme': [bme.loc[Date, 'Msp_32'] if Date in bme.index else np.nan for Date in Index],
                    'vh1': [vh1.loc[Date, 'Msp_32'] if Date in vh1.index else np.nan for Date in Index],
                    'vh2': [vh2.loc[Date, 'Msp_32'] if Date in vh2.index else np.nan for Date in Index],
                    'szeged': [sze.loc[Date, 'Msp_32'] if Date in sze.index else np.nan for Date in Index],
                   },index = Index)

plot = df4.resample('M').mean().plot(figsize=(5,5))
plot.set_title('Msp_32')
plot.set(xlabel='Dátum', ylabel='db')


bme_pref = bme.copy()
for col in bme_pref.columns: 
    if "Msp" not in col:
        #print(col)        
        bme_pref.drop(columns=[col],inplace=True)
        

fig, axs = plt.subplots(3, 3,figsize=(9,9),constrained_layout=True)
for i in range(3):
    for j in range(3):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'linx': [lin.loc[Date, col] if Date in lin.index else np.nan for Date in Index],
                            'jinx': [jin.loc[Date, col] if Date in jin.index else np.nan for Date in Index],
                            'eqix': [eqi.loc[Date, col] if Date in eqi.index else np.nan for Date in Index],
                            'sydney': [syd.loc[Date, col] if Date in syd.index else np.nan for Date in Index],
                            'bme': [bme.loc[Date, col] if Date in bme.index else np.nan for Date in Index],
                            'vh1': [vh1.loc[Date, col] if Date in vh1.index else np.nan for Date in Index],
                            'vh2': [vh2.loc[Date, col] if Date in vh2.index else np.nan for Date in Index],
                            'szeged': [sze.loc[Date, col] if Date in sze.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[i,j].plot(df4.resample('M').mean())
        axs[i,j].set_title(col)
#         axs[i,j].legend(legend)
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    ax.grid()
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])

    
fig, axs = plt.subplots(3, 3,figsize=(9,9), constrained_layout=True)
for i in range(3):
    for j in range(3):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'linx': [lin.loc[Date, col] if Date in lin.index else np.nan for Date in Index],
                            'jinx': [jin.loc[Date, col] if Date in jin.index else np.nan for Date in Index],
                            'eqix': [eqi.loc[Date, col] if Date in eqi.index else np.nan for Date in Index],
                            'sydney': [syd.loc[Date, col] if Date in syd.index else np.nan for Date in Index],
                            'bme': [bme.loc[Date, col] if Date in bme.index else np.nan for Date in Index],
                            'vh1': [vh1.loc[Date, col] if Date in vh1.index else np.nan for Date in Index],
                            'vh2': [vh2.loc[Date, col] if Date in vh2.index else np.nan for Date in Index],
                            'szeged': [sze.loc[Date, col] if Date in sze.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[i,j].plot(df4.resample('M').mean())
        axs[i,j].set_title(col)
#         axs[i,j].legend(legend)
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    ax.grid()
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])

    
fig, axs = plt.subplots(1, 2,figsize=(9,3), constrained_layout=True)
for i in range(1):
    for j in range(2):
        col='Msp_'+str(c)
        
        df4 = pd.DataFrame({'linx': [lin.loc[Date, col] if Date in lin.index else np.nan for Date in Index],
                            'jinx': [jin.loc[Date, col] if Date in jin.index else np.nan for Date in Index],
                            'eqix': [eqi.loc[Date, col] if Date in eqi.index else np.nan for Date in Index],
                            'sydney': [syd.loc[Date, col] if Date in syd.index else np.nan for Date in Index],
                            'bme': [bme.loc[Date, col] if Date in bme.index else np.nan for Date in Index],
                            'vh1': [vh1.loc[Date, col] if Date in vh1.index else np.nan for Date in Index],
                            'vh2': [vh2.loc[Date, col] if Date in vh2.index else np.nan for Date in Index],
                            'szeged': [sze.loc[Date, col] if Date in sze.index else np.nan for Date in Index],
                           },index = Index)
        
        axs[j].plot(df4.resample('M').mean())
        axs[j].set_title(col)
        axs[j].legend(legend,bbox_to_anchor=(1.05, 1), loc='upper left')
        c+=1
for ax in axs.flat:
    ax.set(xlabel='Dátum')
    ax.grid()
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:,.3%}'.format(x) for x in vals])
