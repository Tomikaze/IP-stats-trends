# %%
import pandas as pd
import numpy as np
import os 
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
# D:/TomiKJ/Git Hub/IP-stats-trends/venv/csv/
# D:/Users/Baki/Documents/GitHub/IP-stats-trends/venv/csv/
location ='D:/Users/Baki/Documents/GitHub/IP-stats-trends/venv/csv/'
bme = pd.read_csv(location+"bme.csv",parse_dates=["Date"], index_col="Date")
vh1 = pd.read_csv(location+"vh1.csv",parse_dates=["Date"], index_col="Date")
vh2 = pd.read_csv(location+"vh2.csv",parse_dates=["Date"], index_col="Date")
sze = pd.read_csv(location+"szeged.csv",parse_dates=["Date"], index_col="Date")
lin = pd.read_csv(location+"linx.csv",parse_dates=["Date"], index_col="Date")
kix = pd.read_csv(location+"kixp.csv",parse_dates=["Date"], index_col="Date")
eqi = pd.read_csv(location+"eqix.csv",parse_dates=["Date"], index_col="Date")
syd = pd.read_csv(location+"sydney.csv",parse_dates=["Date"], index_col="Date")

bme.head()
# Out:
#             Total_count  Msp_sum  Pref_1  Pref_2  Pref_3  Pref_4  Pref_5  \
# Date
# 2013-11-13       478068    45241       0       0       0       0       0
# 2013-11-20       478982    45387       0       0       0       0       0
# 2013-11-21       479190    45412       0       0       0       0       0
# 2013-11-22       478766    45406       0       0       0       0       0
# 2013-11-23       479081    45410       0       0       0       0       0
#
#             Pref_6  Pref_7  Pref_8  ...  Msp_24  Msp_25  Msp_26  Msp_27  \
# Date                                ...
# 2013-11-13       0       0      16  ...       9       3       1       4
# 2013-11-20       0       0      16  ...       9       3       1       4
# 2013-11-21       0       0      16  ...       9       3       1       4
# 2013-11-22       0       0      16  ...       9       3       1       4
# 2013-11-23       0       0      16  ...       9       3       1       4
#
# ...

# %%
Index = list(set(list(bme.index) + list(vh1.index )+ list(vh2.index) + list(sze.index)))
Index.sort()

df2 = pd.DataFrame({'bme': [bme.loc[Date, 'Per_8'] if Date in bme.index else np.nan for Date in Index],
                    'vh1': [vh1.loc[Date, 'Per_8'] if Date in vh1.index else np.nan for Date in Index],
                    'vh2': [vh2.loc[Date, 'Per_8'] if Date in vh2.index else np.nan for Date in Index],
                    'szeged': [sze.loc[Date, 'Per_8'] if Date in sze.index else np.nan for Date in Index],
                   },index = Index)
plt.rc('legend', fontsize=18)
plt.rc('axes', labelsize=18) 
plot = df2.plot(figsize=(10,10))
plot.grid()
plot.margins(0)
plot.set_title('Per 8 fedés',fontsize=18)
plot.set(xlabel='Dátum', ylabel='Per 8 ekvivalens')
# Out:
# [Text(0, 0.5, 'Per 8 ekvivalens'), Text(0.5, 0, 'Dátum')]

# %%
plot = df2.plot(figsize=(5,5)).grid()
axes = plt.gca()
axes.set_xlim(['2019-01-10','2019-12-29'])
axes.set_ylim([168.8,170])
axes.get_legend().remove()

# %%
Index = list(set(list(bme.index) + list(vh1.index )+ list(vh2.index) + list(sze.index) +list(lin.index) + list(kix.index )+ list(eqi.index) + list(syd.index)))
Index.sort()

df3 = pd.DataFrame({'linx': [lin.loc[Date, 'Per_8'] if Date in lin.index else np.nan for Date in Index],
                    'kixp': [kix.loc[Date, 'Per_8'] if Date in kix.index else np.nan for Date in Index],
                    'eqix': [eqi.loc[Date, 'Per_8'] if Date in eqi.index else np.nan for Date in Index],
                    'sydney': [syd.loc[Date, 'Per_8'] if Date in syd.index else np.nan for Date in Index],
                    'bme': [bme.loc[Date, 'Per_8'] if Date in bme.index else np.nan for Date in Index],
                    'vh1': [vh1.loc[Date, 'Per_8'] if Date in vh1.index else np.nan for Date in Index],
                    'vh2': [vh2.loc[Date, 'Per_8'] if Date in vh2.index else np.nan for Date in Index],
                    'szeged': [sze.loc[Date, 'Per_8'] if Date in sze.index else np.nan for Date in Index],
                   },index = Index)
# plt.rc('legend', fontsize=18, loc=0)
plt.rc('axes', labelsize=18)
plot1 = df3.plot(figsize=(10,10))
plot1.grid()
plot1.margins(0)
plot1.set_title('Per 8 fedés',fontsize=18)
plot1.set(xlabel='Dátum', ylabel='Per 8 ekvivalens')
plot1.legend(loc='upper right', bbox_to_anchor=(0.25, 1),fontsize=16)

#resample('D').mean()

# %%
plot = df3.plot(figsize=(5,5)).grid()
axes = plt.gca()
axes.set_xlim(['2019-01-10','2019-12-29'])
axes.set_ylim([168.8,170])
axes.get_legend().remove()
